# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import numpy as np

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('train.csv',usecols=['Age'])
df
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
sns.displot(data=df,x='Age',kde=True)
#sns.displot(data=df,x='Age',kde=True)

# %%
plt.subplot(121)
stats.probplot(df['Age'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()

# %%
df=pd.read_csv('Social_Network_Ads.csv',usecols=('Age','EstimatedSalary','Purchased'))

X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,2],test_size=0.2,random_state=42)

# %%
clf = LogisticRegression()
clf2 = DecisionTreeClassifier()

clf.fit(X_train,y_train)
clf2.fit(X_train,y_train)
    
y_pred = clf.predict(X_test)
y_pred1 = clf2.predict(X_test)
    
print("Accuracy LR",accuracy_score(y_test,y_pred))
print("Accuracy DT",accuracy_score(y_test,y_pred1))
# Out:
# Accuracy LR 0.8875
# Accuracy DT 0.8375

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train['EstimatedSalary'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(X_train['EstimatedSalary'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\2852725760.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['EstimatedSalary'])

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train['Age'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(X_train['Age'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17440\2888751792.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'])

# %%
df1=pd.read_csv('cars.csv',usecols=('km_driven','selling_price'))
df1
# Out:
#       km_driven  selling_price
# 0        145500         450000
# 1        120000         370000
# 2        140000         158000
# 3        127000         225000
# 4        120000         130000
# ...         ...            ...
# 8123     110000         320000
# 8124     119000         135000
# 8125     120000         382000
# 8126      25000         290000
# 8127      25000         290000
#
# [8128 rows x 2 columns]

# %%
df2 = pd.concat([df, df1])
df2
# Out:
#        Age  EstimatedSalary  Purchased  km_driven  selling_price
# 0     19.0          19000.0        0.0        NaN            NaN
# 1     35.0          20000.0        0.0        NaN            NaN
# 2     26.0          43000.0        0.0        NaN            NaN
# 3     27.0          57000.0        0.0        NaN            NaN
# 4     19.0          76000.0        0.0        NaN            NaN
# ...    ...              ...        ...        ...            ...
# 8123   NaN              NaN        NaN   110000.0       320000.0
# 8124   NaN              NaN        NaN   119000.0       135000.0
# 8125   NaN              NaN        NaN   120000.0       382000.0
# 8126   NaN              NaN        NaN    25000.0       290000.0
# 8127   NaN              NaN        NaN    25000.0       290000.0
#
# [8528 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df2.iloc[:,0:2],df2.iloc[:,2],test_size=0.2,random_state=42)
df2['Age']=df2['Age'].fillna(df2['Age'].mean())

df2['km_driven']=df2['km_driven'].fillna(df2['km_driven'].mean())
df2['selling_price']=df2['selling_price'].fillna(df2['selling_price'].mean())
sns.distplot(df2['Age'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17440\2807429333.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df2=pd.read_csv("NIFTY_50_COMPANIES.csv")
#df2.isnull().sum()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304543 entries, 0 to 304542
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            304543 non-null  object
#  1   Adj Close       304543 non-null  float64
#  2   Close           304543 non-null  float64
#  3   High            304543 non-null  float64
#  4   Low             304543 non-null  float64
#  5   Open            304543 non-null  float64
#  6   Volume          304543 non-null  int64
#  7   Ticker          304543 non-null  object
#  8   SMA_20          303574 non-null  float64
#  9   SMA_50          302044 non-null  float64
#  10  EMA_12          304543 non-null  float64
#  11  EMA_26          304543 non-null  float64
#  12  MACD            304543 non-null  float64
#  13  Signal_Line     304543 non-null  float64
#  14  RSI_14          301846 non-null  float64
#  15  BB_Mid          303574 non-null  float64
# ...

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(df2['EMA_26'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(df2['EMA_26'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\1839024359.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['EMA_26'])

# %%
#df2['Daily_Return_%']=df2['Daily_Return_%'].fillna(df2['Daily_Return_%'].mean())
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(df2['SMA_50'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(df2['SMA_50'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\3228668320.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['SMA_50'])

# %%
#df2['Daily_Return_%']=df2['Daily_Return_%'].fillna(df2['Daily_Return_%'].mean())
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(df2['EMA_12'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(df2['EMA_12'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\2246708974.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['EMA_12'])

# %%
df2['BB_Upper']=df2['BB_Upper'].fillna(df2['BB_Upper'].mean())
df2.isnull().sum()
# Out:
# Date                 0
# Adj Close            0
# Close                0
# High                 0
# Low                  0
# Open                 0
# Volume               0
# Ticker               0
# SMA_20             969
# SMA_50               0
# EMA_12               0
# EMA_26               0
# MACD                 0
# Signal_Line          0
# RSI_14            2697
# BB_Mid             969
# BB_Upper             0
# BB_Lower           969
# Daily_Return_%       0
# dtype: int64

# %%
df2
# Out:
#               Date   Adj Close       Close        High         Low  \
# 0       1997-07-01    8.918703   13.056603   13.345798   12.924502
# 1       1997-07-02    9.027228   13.215482   13.456477   13.138720
# 2       1997-07-03    8.907730   13.040537   13.263681   12.999478
# 3       1997-07-04    8.754085   12.815608   13.111943   12.735276
# 4       1997-07-07    8.788230   12.865592   13.040537   12.758483
# ...            ...         ...         ...         ...         ...
# 304538  2025-11-05  831.400024  831.400024  831.400024  831.400024
# 304539  2025-11-06  788.400024  788.400024  795.000000  770.150024
# 304540  2025-11-07  790.400024  790.400024  802.599976  783.000000
# 304541  2025-11-10  785.200012  785.200012  799.900024  783.849976
# 304542  2025-11-11  793.750000  793.750000  794.700012  778.099976
#
#               Open     Volume       Ticker      SMA_20      SMA_50  \
# 0        13.281532  442137352  RELIANCE.NS         NaN  914.365179
# ...

# %%
df3=pd.read_csv("NIFTY_50_COMPANIES.csv",usecols=('SMA_50','EMA_12','EMA_26','Daily_Return_%'))

df3['Daily_Return_%']=df3['Daily_Return_%'].fillna(df3['Daily_Return_%'].mean())

df3['SMA_50']=df3['SMA_50'].fillna(df3['SMA_50'].mean())
X_train, X_test, y_train, y_test = train_test_split(df3.iloc[:,0:3],df3.iloc[:,3],test_size=0.2,random_state=42)

# %%
df3['Daily_Return_%']=df3['Daily_Return_%'].fillna(df3['Daily_Return_%'].mean())
df2.isnull().sum()
df3.isnull().sum()
# Out:
# SMA_50            0
# EMA_12            0
# EMA_26            0
# Daily_Return_%    0
# dtype: int64

# %%
trf = FunctionTransformer(func=np.log1p)
#trf.fit_transform(X_train)
#trf.transform(X_test)
X_train_transformed = trf.fit_transform(X_train)
X_test_transformed = trf.transform(X_test)

# %%
#df2['Daily_Return_%']=df2['Daily_Return_%'].fillna(df2['Daily_Return_%'].mean())
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train_transformed['EMA_12'])
plt.title('Age PDF')

plt.subplot(122)
stats.probplot(X_train_transformed['EMA_12'], dist="norm", plot=plt)
plt.title('Age QQ Plot')

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\1363854379.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train_transformed['EMA_12'])

# %%
df3['Daily_Return_%']=df3['Daily_Return_%'].fillna(df3['Daily_Return_%'].mean())
df2.isnull().sum()
df3.isnull().sum()
# Out:
# SMA_50            0
# EMA_12            0
# EMA_26            0
# Daily_Return_%    0
# dtype: int64

# %%
def say(x,y):
    #df2['Daily_Return_%']=df2['Daily_Return_%'].fillna(df2['Daily_Return_%'].mean())
    #df2['Daily_Return_%']=df2['Daily_Return_%'].fillna(df2['Daily_Return_%'].mean())
   plt.figure(figsize=(14,4))
   plt.subplot(121)
   sns.distplot(x[f'{y}'])
   plt.title('Age PDF')

   plt.subplot(122)
   stats.probplot(x[f'{y}'], dist="norm", plot=plt)
   plt.title('Age QQ Plot')

   plt.show()

# %%
say(df3,'EMA_12')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\613959740.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x[f'{y}'])

# %%
say(X_test_transformed,'EMA_12')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13740\613959740.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x[f'{y}'])

# %%
print("hello world " \
"")
# say(X_test_transformed,'SMA_50')

print('how are you ')

print('hello world ' \
'')
import pandas as pd 
hell=[[1,2,3,4,5],[6,7,8,9,20],[11,12,13,14,15]
      ]
no=pd.array(hell)
print(no)
for i in no:
    for j in i:
        print(j)
# Out:
# hello world
# how are you
# hello world
# <NumpyExtensionArray>
# [[1, 2, 3, 4, 5], [6, 7, 8, 9, 20], [11, 12, 13, 14, 15]]
# Length: 3, dtype: object
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 20
# 11
# 12
# 13
# 14
# 15
